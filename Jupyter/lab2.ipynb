# %% [markdown]
# w2a1

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# w2a2

# %%
name = input()
print(f'Hello {name}!')
# Out:
# Hello a!

# %% [markdown]
# w2a3

# %%
a,b = map(int,input().split())
c = a+b
d = a-b
e = a*b
f = a//b
g = a%b
h = a/b
print(a,'+',b,'=',c)
print(a,'-',b,'=',c)
print(a,'*',b,'=',c)
print(a,'//',b,'=',c)
print(a,'%',b,'=',c)
print(f'{h:.2f}')
# Out:
# 7 + 6 = 13
# 7 - 6 = 13
# 7 * 6 = 13
# 7 // 6 = 13
# 7 % 6 = 13
# 1.17

# %% [markdown]
# w2a4

# %%
a1,b1,c1,a2,b2,a3 = map(float,input().split())
tb = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(tb)
if tb < 3.0:
    print('Bro what')
# Out:
# 2.0
# Bro what

# %% [markdown]
# w2a5

# %%
a,b=map(int, input().split())
c=a**b
print(c)
# Out:
# 8

# %% [markdown]
# w2a6

# %%
    w = (input())
    a = ord(w)
    print(a)
    b = a - 97 + 65
    print(chr(b))
# Out:
# 97
# A

# %% [markdown]
# w2a7

# %%
A = ((13 ** 2) * 3) + 5 
B = 13**2*3 + 5
print(A)
print(B)
# Out:
# 512
# 512

# %% [markdown]
# w2a8

# %%
C=float(input())

F = 9/5*C + 32
print(f'{F:.2f}')
# Out:
# 95.00

# %% [markdown]
# w2a9

# %%
x=float(input())
y= x+10+x*10/100+x*30/100
print(f'{y:.2f}')
# Out:
# 80.00

# %% [markdown]
# w2a10

# %%
a,b,c = map(str,input().split())
print(f'Hi {c}, {b} and {a}')
# Out:
# Hi Do, Tu and Cha

# %% [markdown]
# w2a11

# %%
h,m=map(int,input().split())
s=h*3600+m*60
print(f'Gio:{h}, Phut:{m} => Giay:{s}')
# Out:
# Gio:8, Phut:50 => Giay:31800

# %% [markdown]
# w2a12

# %%
n=float(input())
p=n*6
print(f'So hop kho ga can la:{p}')
# Out:
# So hop kho ga can la:12.0

# %% [markdown]
# w2a13

# %%
a,b=map(int, input().split())
c=a*b
print(c%10)
# Out:
# 2

# %% [markdown]
# w2a14

# %%
a,b=map(float, input('Nhap so a va b').split())
print(f'So a la {b}, so b la {a}')
# Out:
# So a la 6.0, so b la 7.0

# %% [markdown]
# w2a15

# %%
n=float(input())
m = 6*n*(n-1)+1
print(m)
# Out:
# 121.0

# %% [markdown]
# w2a16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# w2a17

# %%
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %% [markdown]
# w2a18

# %%
print("### # # ### ###")
print("")
print("")
print("")
print("")
